# %% [markdown]
# # Short - Straddle Intraday With Take Profit

# %%
import pandas as pd
import numpy as np
import os
from datetime import datetime, timedelta

# === CONFIG ===
ENTRY_WINDOW_START = "09:20:00"  # Start of entry window for finding optimal entry
ENTRY_WINDOW_END = "09:45:00"    # End of entry window for finding optimal entry
EXIT_TIME = "15:15:00"
SLIPPAGE = 0.005  # per leg
LOTSIZE = 375
BROKERAGE_PER_LEG = 0.5  # per leg per lot
SL_PCT = 0.10
TP_RATIO = 2  # Take profit at 1.5x the risk (e.g., if risking 10%, take profit at 15% gain)
INITIAL_CAPITAL = 1000000
MAX_REENTRIES = 3  # Maximum number of re-entries after stop loss
DATA_FOLDER = r"C:\Users\omdes\Desktop\QuantInsti\AlphaNiti Assignment\Options data\APR_2021"

def load_data(folder_path):
    """
    Load and combine all CSV files from the specified folder
    """
    all_data = []
    for file in os.listdir(folder_path):
        if file.endswith(".csv"):
            file_path = os.path.join(folder_path, file)
            try:
                df = pd.read_csv(file_path)
                # Combine Date + Time into timestamp
                df['timestamp'] = pd.to_datetime(df['Date'] + ' ' + df['Time'], dayfirst=True)
                # Standardize column names
                df.columns = df.columns.str.lower().str.replace(" ", "_")
                all_data.append(df)
            except Exception as e:
                print(f"Error loading {file}: {e}")
    
    if all_data:
        df_all = pd.concat(all_data).reset_index(drop=True)
        print("Combined Data Shape:", df_all.shape)
        print(df_all[['ticker', 'timestamp', 'open', 'high', 'low', 'close']].head())
        return df_all
    else:
        print("No data loaded!")
        return None

def get_atm_strike_and_prices(df_day, timestamp=None):
    """
    Identify the ATM strike and return its CE/PE tickers
    
    Parameters:
    df_day - DataFrame with day's data
    timestamp - Optional specific timestamp to use (for re-entries)
    """
    if timestamp:
        # For re-entries, use the specified timestamp with a 2-minute window
        ts_time = pd.to_datetime(timestamp)
        start_time = (ts_time - timedelta(minutes=1)).strftime('%H:%M:%S')
        end_time = (ts_time + timedelta(minutes=1)).strftime('%H:%M:%S')
        window_df = df_day[df_day['timestamp'].dt.strftime('%H:%M:%S').between(start_time, end_time)]
    else:
        # For initial entry, use the specified entry window
        window_df = df_day[df_day['timestamp'].dt.strftime('%H:%M:%S').between(ENTRY_WINDOW_START, ENTRY_WINDOW_END)]
    
    window_df = window_df[window_df['ticker'].str.startswith("NIFTY")].copy()

    if window_df.empty:
        return None, None, None

    window_df['strike'] = window_df['ticker'].str.extract(r'NIFTY\d{2}[A-Z]{3}\d{2}(\d{4,5})').astype(float)
    window_df['option_type'] = window_df['ticker'].str.extract(r'(CE|PE)')

    # Group by timestamp and strike to find ATM strike at each timestamp
    atm_candidates = []
    for ts, group in window_df.groupby('timestamp'):
        pivot = group.pivot_table(index='strike', columns='option_type', values='close', aggfunc='mean')
        if 'CE' in pivot.columns and 'PE' in pivot.columns:
            pivot = pivot.dropna()
            pivot['diff'] = abs(pivot['CE'] - pivot['PE'])
            
            if not pivot.empty:
                atm_strike = pivot['diff'].idxmin()
                ce_price = pivot.loc[atm_strike, 'CE']
                pe_price = pivot.loc[atm_strike, 'PE']
                premium_sum = ce_price + pe_price
                
                atm_candidates.append({
                    'timestamp': ts,
                    'strike': atm_strike,
                    'ce_price': ce_price,
                    'pe_price': pe_price,
                    'premium_sum': premium_sum
                })
    
    if not atm_candidates:
        return None, None, None
    
    # Sort by premium sum (highest premium = best initial entry for short straddle)
    atm_candidates_df = pd.DataFrame(atm_candidates)
    best_entry = atm_candidates_df.sort_values('premium_sum', ascending=False).iloc[0]
    
    optimal_ts = best_entry['timestamp']
    atm_strike = best_entry['strike']
    
    # Extract tickers for optimal strike
    ts_time = optimal_ts.strftime('%H:%M:%S')
    ts_window_df = window_df[window_df['timestamp'].dt.strftime('%H:%M:%S') == ts_time]
    
    ce_ticker = ts_window_df[(ts_window_df['strike'] == atm_strike) & 
                        (ts_window_df['option_type'] == 'CE')]['ticker'].iloc[0]
    pe_ticker = ts_window_df[(ts_window_df['strike'] == atm_strike) & 
                        (ts_window_df['option_type'] == 'PE')]['ticker'].iloc[0]

    entry_time = optimal_ts if not timestamp else timestamp
    print(f"\nBest Entry Found at: {entry_time.strftime('%H:%M:%S')}")
    print(f"ATM Strike: {atm_strike}")
    print(f"CE Ticker: {ce_ticker}, Premium: {best_entry['ce_price']}")
    print(f"PE Ticker: {pe_ticker}, Premium: {best_entry['pe_price']}")
    print(f"Total Premium: {best_entry['premium_sum']}")

    return atm_strike, ce_ticker, pe_ticker, optimal_ts

def backtest_short_straddle(df_all, date):
    """
    Backtest short straddle strategy for a specific date with re-entries
    """
    print(f"\n=== Backtesting for {date} ===")
    df_day = df_all[df_all['timestamp'].dt.date == pd.to_datetime(date).date()]
    df_day = df_day[df_day['ticker'].str.startswith("NIFTY")]

    if df_day.empty:
        print(f"No data available for {date}")
        return None

    # List to store all trades for this day
    all_trades = []
    
    # Track the number of entries made today
    entry_count = 0
    
    # Get initial tickers with optimal entry time
    atm_strike, ce_ticker, pe_ticker, optimal_entry_time = get_atm_strike_and_prices(df_day)
    if not atm_strike:
        print(f"Could not determine ATM strike for {date}")
        return None
    
    # Extract all timestamps for the day
    all_timestamps = sorted(df_day['timestamp'].unique())
    
    # Initialize for first entry using optimal time
    next_entry_time = optimal_entry_time
    
    # Continue trading until we hit max entries or market close
    while entry_count <= MAX_REENTRIES and next_entry_time.strftime('%H:%M:%S') <= EXIT_TIME:
        # Check if this is a re-entry
        is_reentry = entry_count > 0
        
        if is_reentry:
            # For re-entries, get new ATM strikes based on current market conditions
            atm_strike, ce_ticker, pe_ticker, _ = get_atm_strike_and_prices(df_day, next_entry_time)
            if not atm_strike:
                print(f"Could not determine ATM strike for re-entry at {next_entry_time}")
                break
        
        # Get data for selected tickers
        ce_df = df_day[df_day['ticker'] == ce_ticker]
        pe_df = df_day[df_day['ticker'] == pe_ticker]
        
        # Find entry prices
        ce_entry_row = ce_df[ce_df['timestamp'] == next_entry_time]
        pe_entry_row = pe_df[pe_df['timestamp'] == next_entry_time]
        
        if ce_entry_row.empty or pe_entry_row.empty:
            print(f"Entry data not available at {next_entry_time} for {date}")
            break
        
        # Entry prices
        ce_entry = ce_entry_row['close'].iloc[0]
        pe_entry = pe_entry_row['close'].iloc[0]
        gross_entry = ce_entry + pe_entry
        
        # Calculate SL and TP levels
        sl_premium = gross_entry * (1 + SL_PCT)
        risk_amount = sl_premium - gross_entry
        tp_gain = risk_amount * TP_RATIO
        tp_premium = gross_entry - tp_gain
        
        if tp_premium < 0:
            print(f"Warning: Take profit level calculated as {tp_premium}, which is negative. Using 0.5x entry premium.")
            tp_premium = gross_entry * 0.5
        
        entry_time_str = next_entry_time.strftime('%H:%M:%S')
        entry_label = "REENTRY" if is_reentry else "INITIAL"
        
        print(f"\n--- {entry_label} ENTRY #{entry_count+1} at {entry_time_str} ---")
        print(f"CE Entry (SELL): {ce_entry}")
        print(f"PE Entry (SELL): {pe_entry}")
        print(f"Gross Premium Received: {gross_entry}")
        print(f"Stop Loss Premium Level: {sl_premium} (Risk: {SL_PCT*100}%)")
        print(f"Take Profit Premium Level: {tp_premium} (Reward: {TP_RATIO}x risk)")
        
        # Track this trade
        merged = pd.merge(
            ce_df[['timestamp', 'close']],
            pe_df[['timestamp', 'close']],
            on='timestamp',
            suffixes=('_ce', '_pe')
        ).sort_values('timestamp')
        
        # Only consider data after this entry time
        merged = merged[merged['timestamp'] >= next_entry_time]
        
        # Trade management variables
        active_trade = True
        next_entry_time = None  # Will be set if SL is hit and we need to re-enter
        
        for _, row in merged.iterrows():
            ts = row['timestamp']
            if ts.strftime('%H:%M:%S') > EXIT_TIME:
                break
                
            curr_premium = row['close_ce'] + row['close_pe']
            
            # Check for stop loss hit
            if active_trade and curr_premium >= sl_premium:
                # Calculate PnL for a short position: (entry - exit) * lotsize - brokerage
                pnl = (gross_entry - curr_premium - (2 * BROKERAGE_PER_LEG)) * LOTSIZE
                all_trades.append({
                    'date': date,
                    'entry_number': entry_count + 1,
                    'entry_type': entry_label,
                    'entry_time': next_entry_time,
                    'exit_time': ts,
                    'ce_entry': ce_entry,
                    'pe_entry': pe_entry,
                    'ce_exit': row['close_ce'],
                    'pe_exit': row['close_pe'],
                    'exit_reason': 'SL_HIT',
                    'PnL': pnl
                })
                active_trade = False
                print(f"SL hit at {ts.strftime('%H:%M:%S')} - PnL: {pnl}")
                
                # Set up for re-entry if we haven't hit the maximum
                if entry_count < MAX_REENTRIES:
                    next_entry_time = ts  # Re-enter at the time of SL hit
                    entry_count += 1
                break
                
            # Check for take profit hit
            if active_trade and curr_premium <= tp_premium:
                pnl = (gross_entry - curr_premium - (2 * BROKERAGE_PER_LEG)) * LOTSIZE
                all_trades.append({
                    'date': date,
                    'entry_number': entry_count + 1,
                    'entry_type': entry_label,
                    'entry_time': next_entry_time,
                    'exit_time': ts,
                    'ce_entry': ce_entry,
                    'pe_entry': pe_entry,
                    'ce_exit': row['close_ce'],
                    'pe_exit': row['close_pe'],
                    'exit_reason': 'TP_HIT',
                    'PnL': pnl
                })
                active_trade = False
                print(f"TP hit at {ts.strftime('%H:%M:%S')} - PnL: {pnl}")
                # No re-entry after TP hit - we're done for the day
                next_entry_time = None
                break
        
        # If we made it to market close without hitting SL or TP
        if active_trade:
            last = merged[merged['timestamp'].dt.strftime('%H:%M:%S') <= EXIT_TIME].iloc[-1]
            curr_premium = last['close_ce'] + last['close_pe']
            pnl = (gross_entry - curr_premium - (2 * BROKERAGE_PER_LEG)) * LOTSIZE
            all_trades.append({
                'date': date,
                'entry_number': entry_count + 1,
                'entry_type': entry_label,
                'entry_time': next_entry_time,
                'exit_time': last['timestamp'],
                'ce_entry': ce_entry,
                'pe_entry': pe_entry,
                'ce_exit': last['close_ce'],
                'pe_exit': last['close_pe'],
                'exit_reason': 'MARKET_CLOSE',
                'PnL': pnl
            })
            print(f"Position closed at market close - PnL: {pnl}")
            # No more trading after market close
            break
        
        # If no next entry time was set (TP hit or other reason), break the loop
        if next_entry_time is None:
            break
            
        # Move to the next entry
        entry_count += 1 if entry_count == 0 else 0  # Only increment if this was the first entry
    
    if all_trades:
        return pd.DataFrame(all_trades)
    else:
        print(f"No trades executed for {date}")
        return None

def generate_performance_report(results_df):
    """
    Generate performance metrics from backtest results
    """
    results_df['date'] = pd.to_datetime(results_df['date'])
    results_df = results_df.sort_values(['date', 'entry_time'])

    # Add daily statistics
    daily_stats = []
    for date, group in results_df.groupby('date'):
        daily_pnl = group['PnL'].sum()
        daily_stats.append({
            'date': date,
            'trades': len(group),
            'daily_pnl': daily_pnl
        })
    
    daily_df = pd.DataFrame(daily_stats)
    daily_df['cum_pnl'] = daily_df['daily_pnl'].cumsum()
    daily_df['equity'] = INITIAL_CAPITAL + daily_df['cum_pnl']
    daily_df['daily_return'] = daily_df['daily_pnl'] / daily_df['equity'].shift(1)
    daily_df['daily_return'] = daily_df['daily_return'].fillna(0)

    # === Performance Metrics ===
    total_days = len(daily_df)
    profitable_days = sum(daily_df['daily_pnl'] > 0)
    win_rate_days = profitable_days / total_days if total_days > 0 else 0
    
    total_trades = len(results_df)
    profitable_trades = sum(results_df['PnL'] > 0)
    win_rate_trades = profitable_trades / total_trades if total_trades > 0 else 0
    
    # Segregate by exit reason
    sl_hits = sum(results_df['exit_reason'] == 'SL_HIT')
    tp_hits = sum(results_df['exit_reason'] == 'TP_HIT')
    market_closes = sum(results_df['exit_reason'] == 'MARKET_CLOSE')
    
    # Re-entry statistics
    entry_counts = results_df.groupby('date')['entry_number'].max().value_counts().sort_index()
    avg_entries_per_day = results_df.groupby('date')['entry_number'].max().mean()
    
    total_return = daily_df['equity'].iloc[-1] - INITIAL_CAPITAL
    percentage_return = (total_return / INITIAL_CAPITAL) * 100
    
    max_drawdown = (daily_df['equity'].cummax() - daily_df['equity']).max()
    max_drawdown_pct = max_drawdown / daily_df['equity'].cummax().max() * 100
    
    # Annualized metrics (assuming 252 trading days in a year)
    days_elapsed = (daily_df['date'].iloc[-1] - daily_df['date'].iloc[0]).days
    years = days_elapsed / 365
    cagr = ((daily_df['equity'].iloc[-1] / INITIAL_CAPITAL) ** (1 / years if years > 0 else 1)) - 1
    sharpe = daily_df['daily_return'].mean() / daily_df['daily_return'].std() * np.sqrt(252) if daily_df['daily_return'].std() > 0 else 0

    print("\n==== Performance Summary ====")
    print(f"Total Days     : {total_days}")
    print(f"Total Trades   : {total_trades}")
    print(f"Avg Trades/Day : {total_trades / total_days:.2f}")
    print(f"Avg Entries/Day: {avg_entries_per_day:.2f}")
    print(f"Win Rate (Days): {win_rate_days:.2%}")
    print(f"Win Rate (Trades): {win_rate_trades:.2%}")
    print(f"Total Return   : ₹{total_return:.2f} ({percentage_return:.2f}%)")
    print(f"Max Drawdown   : ₹{max_drawdown:.2f} ({max_drawdown_pct:.2f}%)")
    print(f"CAGR           : {cagr * 100:.2f}%")
    print(f"Sharpe Ratio   : {sharpe:.2f}")
    
    print("\n==== Entry Statistics ====")
    for entry_num, count in entry_counts.items():
        print(f"{entry_num} Entry(ies): {count} days ({count/total_days:.2%} of days)")
    
    print("\n==== Exit Statistics ====")
    print(f"Stop Loss Hits : {sl_hits} ({sl_hits/total_trades:.2%} of trades)")
    print(f"Take Profit Hits: {tp_hits} ({tp_hits/total_trades:.2%} of trades)")
    print(f"Market Close   : {market_closes} ({market_closes/total_trades:.2%} of trades)")

    # === Daily Table ===
    summary_table = daily_df[['date', 'trades', 'daily_pnl', 'equity']].copy()
    summary_table.columns = ['Date', 'Trades', 'Daily PnL', 'Capital']
    summary_table['Date'] = summary_table['Date'].dt.strftime('%Y-%m-%d')
    summary_table['Daily PnL'] = summary_table['Daily PnL'].map(lambda x: f"{x:+,.2f}")
    summary_table['Capital'] = summary_table['Capital'].map(lambda x: f"{x:,.2f}")

    print("\n==== Daily Capital & PnL ====")
    print(summary_table.to_string(index=False))

    # Return combined daily and trade data
    return {
        'daily': daily_df,
        'trades': results_df
    }

def run_backtest(start_date, end_date):
    """
    Run the backtest for a specified date range
    """
    print(f"==== Running Short Straddle Backtest with Re-entries ====")
    print(f"Date Range: {start_date} to {end_date}")
    print(f"Entry Window: {ENTRY_WINDOW_START} to {ENTRY_WINDOW_END} (finding optimal entry)")
    print(f"Exit Time: {EXIT_TIME}")
    print(f"Lot Size: {LOTSIZE}")
    print(f"Stop Loss: {SL_PCT*100}% of entry premium")
    print(f"Take Profit: {TP_RATIO}x risk (reward-to-risk ratio)")
    print(f"Max Re-entries: {MAX_REENTRIES}")
    print(f"Initial Capital: ₹{INITIAL_CAPITAL:,}")
    
    # Load data
    df_all = load_data(DATA_FOLDER)
    if df_all is None:
        return
    
    # Get all trading days in the specified range
    all_dates = pd.date_range(start=start_date, end=end_date, freq='B')
    all_trades = []

    for d in all_dates:
        day_result = backtest_short_straddle(df_all, d.strftime('%Y-%m-%d'))
        if day_result is not None:
            all_trades.append(day_result)

    if all_trades:
        results = pd.concat(all_trades)
        results_data = generate_performance_report(results)
        
        # Export results to CSV
        trade_filename = f"ShortStraddle_Trades_{start_date}_to_{end_date}.csv"
        daily_filename = f"ShortStraddle_Daily_{start_date}_to_{end_date}.csv"
        
        results_data['trades'].to_csv(trade_filename, index=False)
        results_data['daily'].to_csv(daily_filename, index=False)
        
        print(f"\nTrade results exported to {trade_filename}")
        print(f"Daily results exported to {daily_filename}")
        
        return results_data
    else:
        print("No trades executed during the backtest period.")
        return None

# === MAIN EXECUTION ===
if __name__ == "__main__":
    start_date = '2021-04-01'
    end_date = '2021-04-30'
    
    results_data = run_backtest(start_date, end_date)
    
    if results_data is not None:
        # You can add code here to create plots or additional analysis
        print("\nBacktest completed successfully!")
    else:
        print("\nBacktest failed to execute properly.")
# Out:
# ==== Running Short Straddle Backtest with Re-entries ====
# Date Range: 2021-04-01 to 2021-04-30
# Entry Window: 09:20:00 to 09:45:00 (finding optimal entry)
# Exit Time: 15:15:00
# Lot Size: 375
# Stop Loss: 10.0% of entry premium
# Take Profit: 2x risk (reward-to-risk ratio)
# Max Re-entries: 3
# Initial Capital: ₹1,000,000
# Combined Data Shape: (12459881, 10)
#                       ticker           timestamp  open  high   low  close
# 0  AARTIIND29APR211100PE.NFO 2021-04-01 14:16:59   2.2   2.2  2.20   2.20
# 1  AARTIIND29APR211200PE.NFO 2021-04-01 10:16:59   8.5   8.5  8.50   8.50
# 2  AARTIIND29APR211200PE.NFO 2021-04-01 11:43:59   8.5   8.5  8.50   8.50
# 3  AARTIIND29APR211200PE.NFO 2021-04-01 12:36:59   8.5   8.5  6.05   6.05
# 4  AARTIIND29APR211200PE.NFO 2021-04-01 12:37:59   6.1   6.1  6.10   6.10
#
# === Backtesting for 2021-04-01 ===
#
# Best Entry Found at: 09:43:59
# ATM Strike: 15000.0
# CE Ticker: NIFTY01APR2115000CE.NFO, Premium: 315.7416666666667
# PE Ticker: NIFTY01APR2115000PE.NFO, Premium: 351.65
# Total Premium: 667.3916666666667
#
# --- INITIAL ENTRY #1 at 09:43:59 ---
# CE Entry (SELL): 2.55
# PE Entry (SELL): 230.0
# Gross Premium Received: 232.55
# Stop Loss Premium Level: 255.80500000000004 (Risk: 10.0%)
# Take Profit Premium Level: 186.03999999999996 (Reward: 2x risk)
# SL hit at 10:40:59 - PnL: -9581.249999999984
#
# Best Entry Found at: 10:40:59
# ATM Strike: 14700.0
# CE Ticker: NIFTY01APR2114700CE.NFO, Premium: 217.2166666666667
# PE Ticker: NIFTY01APR2114700PE.NFO, Premium: 197.03000000000003
# Total Premium: 414.2466666666667
#
# --- REENTRY ENTRY #2 at 10:40:59 ---
# CE Entry (SELL): 77.7
# PE Entry (SELL): 31.3
# Gross Premium Received: 109.0
# Stop Loss Premium Level: 119.9 (Risk: 10.0%)
# Take Profit Premium Level: 87.19999999999999 (Reward: 2x risk)
# SL hit at 13:15:59 - PnL: -8512.499999999996
#
# Best Entry Found at: 13:15:59
# ATM Strike: 14850.0
# CE Ticker: NIFTY01APR2114850CE.NFO, Premium: 165.5875
# PE Ticker: NIFTY01APR2114850PE.NFO, Premium: 169.3
# Total Premium: 334.88750000000005
#
# --- REENTRY ENTRY #3 at 13:15:59 ---
# CE Entry (SELL): 19.05
# PE Entry (SELL): 58.25
# Gross Premium Received: 77.3
# Stop Loss Premium Level: 85.03 (Risk: 10.0%)
# Take Profit Premium Level: 61.83999999999999 (Reward: 2x risk)
# TP hit at 14:10:59 - PnL: 5737.499999999999
#
# === Backtesting for 2021-04-02 ===
# No data available for 2021-04-02
#
# === Backtesting for 2021-04-05 ===
#
# Best Entry Found at: 09:33:59
# ATM Strike: 15000.0
# CE Ticker: NIFTY08APR2115000CE.NFO, Premium: 396.875
# PE Ticker: NIFTY08APR2115000PE.NFO, Premium: 417.5799999999999
# Total Premium: 814.4549999999999
#
# --- INITIAL ENTRY #1 at 09:33:59 ---
# CE Entry (SELL): 52.05
# PE Entry (SELL): 268.55
# Gross Premium Received: 320.6
# Stop Loss Premium Level: 352.6600000000001 (Risk: 10.0%)
# Take Profit Premium Level: 256.4799999999999 (Reward: 2x risk)
# SL hit at 09:57:59 - PnL: -19443.749999999985
#
# Best Entry Found at: 09:57:59
# ATM Strike: 14700.0
# CE Ticker: NIFTY08APR2114700CE.NFO, Premium: 303.15999999999997
# PE Ticker: NIFTY08APR2114700PE.NFO, Premium: 267.7875
# Total Premium: 570.9475
#
# --- REENTRY ENTRY #2 at 09:57:59 ---
# CE Entry (SELL): 137.75
# PE Entry (SELL): 146.1
# Gross Premium Received: 283.85
# Stop Loss Premium Level: 312.23500000000007 (Risk: 10.0%)
# Take Profit Premium Level: 227.07999999999993 (Reward: 2x risk)
# SL hit at 10:02:59 - PnL: -11662.499999999987
#
# Best Entry Found at: 10:02:59
# ATM Strike: 14500.0
# CE Ticker: NIFTY08APR2114500CE.NFO, Premium: 373.67499999999995
# PE Ticker: NIFTY08APR2114500PE.NFO, Premium: 354.82142857142856
# Total Premium: 728.4964285714285
#
# --- REENTRY ENTRY #3 at 10:02:59 ---
# CE Entry (SELL): 204.55
# PE Entry (SELL): 116.9
# Gross Premium Received: 321.45000000000005
# Stop Loss Premium Level: 353.5950000000001 (Risk: 10.0%)
# Take Profit Premium Level: 257.15999999999997 (Reward: 2x risk)
# Position closed at market close - PnL: 9750.000000000022
#
# === Backtesting for 2021-04-06 ===
#
# Best Entry Found at: 09:26:59
# ATM Strike: 14700.0
# CE Ticker: NIFTY08APR2114700CE.NFO, Premium: 279.48999999999995
# PE Ticker: NIFTY08APR2114700PE.NFO, Premium: 269.7125
# Total Premium: 549.2024999999999
#
# --- INITIAL ENTRY #1 at 09:26:59 ---
# CE Entry (SELL): 110.3
# PE Entry (SELL): 136.5
# Gross Premium Received: 246.8
# Stop Loss Premium Level: 271.48 (Risk: 10.0%)
# Take Profit Premium Level: 197.44 (Reward: 2x risk)
# Position closed at market close - PnL: 17287.500000000007
#
# === Backtesting for 2021-04-07 ===
#
# Best Entry Found at: 09:41:59
# ATM Strike: 14800.0
# CE Ticker: NIFTY08APR2114800CE.NFO, Premium: 245.775
# PE Ticker: NIFTY08APR2114800PE.NFO, Premium: 263.7375
# Total Premium: 509.51250000000005
#
# --- INITIAL ENTRY #1 at 09:41:59 ---
# CE Entry (SELL): 68.0
# PE Entry (SELL): 130.5
# Gross Premium Received: 198.5
# Stop Loss Premium Level: 218.35000000000002 (Risk: 10.0%)
# Take Profit Premium Level: 158.79999999999995 (Reward: 2x risk)
# TP hit at 13:40:59 - PnL: 15000.0
#
# === Backtesting for 2021-04-08 ===
#
# Best Entry Found at: 09:37:59
# ATM Strike: 15000.0
# CE Ticker: NIFTY08APR2115000CE.NFO, Premium: 391.8071428571429
# PE Ticker: NIFTY08APR2115000PE.NFO, Premium: 379.625
# Total Premium: 771.4321428571429
#
# --- INITIAL ENTRY #1 at 09:37:59 ---
# CE Entry (SELL): 15.5
# PE Entry (SELL): 87.0
# Gross Premium Received: 102.5
# Stop Loss Premium Level: 112.75000000000001 (Risk: 10.0%)
# Take Profit Premium Level: 81.99999999999997 (Reward: 2x risk)
# TP hit at 11:01:59 - PnL: 7500.0
#
# === Backtesting for 2021-04-09 ===
#
# Best Entry Found at: 09:26:59
# ATM Strike: 14900.0
# CE Ticker: NIFTY15APR2114900CE.NFO, Premium: 266.1125
# PE Ticker: NIFTY15APR2114900PE.NFO, Premium: 276.025
# Total Premium: 542.1375
#
# --- INITIAL ENTRY #1 at 09:26:59 ---
# CE Entry (SELL): 128.05
# PE Entry (SELL): 175.05
# Gross Premium Received: 303.1
# Stop Loss Premium Level: 333.41 (Risk: 10.0%)
# Take Profit Premium Level: 242.48000000000002 (Reward: 2x risk)
# Position closed at market close - PnL: 16612.500000000004
#
# === Backtesting for 2021-04-12 ===
#
# Best Entry Found at: 09:31:59
# ATM Strike: 14500.0
# CE Ticker: NIFTY15APR2114500CE.NFO, Premium: 458.51666666666665
# PE Ticker: NIFTY06MAY2114500PE.NFO, Premium: 410.1714285714285
# Total Premium: 868.6880952380952
#
# --- INITIAL ENTRY #1 at 09:31:59 ---
# CE Entry (SELL): 113.0
# PE Entry (SELL): 351.0
# Gross Premium Received: 464.0
# Stop Loss Premium Level: 510.40000000000003 (Risk: 10.0%)
# Take Profit Premium Level: 371.19999999999993 (Reward: 2x risk)
# Position closed at market close - PnL: -9524.99999999999
#
# === Backtesting for 2021-04-13 ===
#
# Best Entry Found at: 09:20:59
# ATM Strike: 14300.0
# CE Ticker: NIFTY15APR2114300CE.NFO, Premium: 282.5875
# PE Ticker: NIFTY15APR2114300PE.NFO, Premium: 248.925
# Total Premium: 531.5125
#
# --- INITIAL ENTRY #1 at 09:20:59 ---
# CE Entry (SELL): 120.05
# PE Entry (SELL): 123.5
# Gross Premium Received: 243.55
# Stop Loss Premium Level: 267.90500000000003 (Risk: 10.0%)
# Take Profit Premium Level: 194.83999999999997 (Reward: 2x risk)
# TP hit at 12:10:59 - PnL: 18018.750000000004
#
# === Backtesting for 2021-04-14 ===
# No data available for 2021-04-14
#
# === Backtesting for 2021-04-15 ===
#
# Best Entry Found at: 09:35:59
# ATM Strike: 14500.0
# CE Ticker: NIFTY06MAY2114500CE.NFO, Premium: 302.47499999999997
# PE Ticker: NIFTY06MAY2114500PE.NFO, Premium: 260.075
# Total Premium: 562.55
#
# --- INITIAL ENTRY #1 at 09:35:59 ---
# CE Entry (SELL): 332.65
# PE Entry (SELL): 283.4
# Gross Premium Received: 616.05
# Stop Loss Premium Level: 677.655 (Risk: 10.0%)
# Take Profit Premium Level: 492.8399999999999 (Reward: 2x risk)
# Position closed at market close - PnL: 6206.249999999983
#
# === Backtesting for 2021-04-16 ===
#
# Best Entry Found at: 09:31:59
# ATM Strike: 14600.0
# CE Ticker: NIFTY06MAY2114600CE.NFO, Premium: 296.675
# PE Ticker: NIFTY22APR2114600PE.NFO, Premium: 284.775
# Total Premium: 581.45
#
# --- INITIAL ENTRY #1 at 09:31:59 ---
# CE Entry (SELL): 320.0
# PE Entry (SELL): 137.0
# Gross Premium Received: 457.0
# Stop Loss Premium Level: 502.70000000000005 (Risk: 10.0%)
# Take Profit Premium Level: 365.5999999999999 (Reward: 2x risk)
# Position closed at market close - PnL: 10162.50000000001
#
# === Backtesting for 2021-04-19 ===
#
# Best Entry Found at: 09:30:59
# ATM Strike: 14400.0
# CE Ticker: NIFTY22APR2114400CE.NFO, Premium: 326.975
# PE Ticker: NIFTY22APR2114400PE.NFO, Premium: 331.09999999999997
# Total Premium: 658.075
#
# --- INITIAL ENTRY #1 at 09:30:59 ---
# CE Entry (SELL): 75.45
# PE Entry (SELL): 242.8
# Gross Premium Received: 318.25
# Stop Loss Premium Level: 350.07500000000005 (Risk: 10.0%)
# Take Profit Premium Level: 254.5999999999999 (Reward: 2x risk)
# TP hit at 13:58:59 - PnL: 25518.750000000004
#
# === Backtesting for 2021-04-20 ===
#
# Best Entry Found at: 09:44:59
# ATM Strike: 14500.0
# CE Ticker: NIFTY06MAY2114500CE.NFO, Premium: 306.56000000000006
# PE Ticker: NIFTY06MAY2114500PE.NFO, Premium: 362.90000000000003
# Total Premium: 669.46
#
# --- INITIAL ENTRY #1 at 09:44:59 ---
# CE Entry (SELL): 267.95
# PE Entry (SELL): 263.6
# Gross Premium Received: 531.55
# Stop Loss Premium Level: 584.705 (Risk: 10.0%)
# Take Profit Premium Level: 425.2399999999998 (Reward: 2x risk)
# Position closed at market close - PnL: -5643.7500000000255
#
# === Backtesting for 2021-04-21 ===
# No data available for 2021-04-21
#
# === Backtesting for 2021-04-22 ===
#
# Best Entry Found at: 09:22:59
# ATM Strike: 14300.0
# CE Ticker: NIFTY06MAY2114300CE.NFO, Premium: 260.7
# PE Ticker: NIFTY06MAY2114300PE.NFO, Premium: 267.2
# Total Premium: 527.9
#
# --- INITIAL ENTRY #1 at 09:22:59 ---
# CE Entry (SELL): 235.25
# PE Entry (SELL): 301.7
# Gross Premium Received: 536.95
# Stop Loss Premium Level: 590.6450000000001 (Risk: 10.0%)
# Take Profit Premium Level: 429.55999999999995 (Reward: 2x risk)
# Position closed at market close - PnL: -13068.749999999965
#
# === Backtesting for 2021-04-23 ===
#
# Best Entry Found at: 09:30:59
# ATM Strike: 14300.0
# CE Ticker: NIFTY06MAY2114300CE.NFO, Premium: 318.725
# PE Ticker: NIFTY06MAY2114300PE.NFO, Premium: 308.98
# Total Premium: 627.705
#
# --- INITIAL ENTRY #1 at 09:30:59 ---
# CE Entry (SELL): 290.9
# PE Entry (SELL): 249.95
# Gross Premium Received: 540.8499999999999
# Stop Loss Premium Level: 594.935 (Risk: 10.0%)
# Take Profit Premium Level: 432.67999999999984 (Reward: 2x risk)
# Position closed at market close - PnL: 7912.499999999965
#
# === Backtesting for 2021-04-26 ===
#
# Best Entry Found at: 09:29:59
# ATM Strike: 14500.0
# CE Ticker: NIFTY06MAY2114500CE.NFO, Premium: 441.94166666666666
# PE Ticker: NIFTY06MAY2114500PE.NFO, Premium: 387.98333333333335
# Total Premium: 829.925
#
# --- INITIAL ENTRY #1 at 09:29:59 ---
# CE Entry (SELL): 234.2
# PE Entry (SELL): 247.4
# Gross Premium Received: 481.6
# Stop Loss Premium Level: 529.7600000000001 (Risk: 10.0%)
# Take Profit Premium Level: 385.27999999999986 (Reward: 2x risk)
# Position closed at market close - PnL: 11418.750000000016
#
# === Backtesting for 2021-04-27 ===
#
# Best Entry Found at: 09:41:59
# ATM Strike: 14500.0
# CE Ticker: NIFTY06MAY2114500CE.NFO, Premium: 278.9375
# PE Ticker: NIFTY06MAY2114500PE.NFO, Premium: 278.1
# Total Premium: 557.0375
#
# --- INITIAL ENTRY #1 at 09:41:59 ---
# CE Entry (SELL): 238.55
# PE Entry (SELL): 196.0
# Gross Premium Received: 434.55
# Stop Loss Premium Level: 478.00500000000005 (Risk: 10.0%)
# Take Profit Premium Level: 347.63999999999993 (Reward: 2x risk)
# Position closed at market close - PnL: 3206.250000000004
#
# === Backtesting for 2021-04-28 ===
#
# Best Entry Found at: 09:26:59
# ATM Strike: 14800.0
# CE Ticker: NIFTY06MAY2114800CE.NFO, Premium: 253.93
# PE Ticker: NIFTY06MAY2114800PE.NFO, Premium: 289.61
# Total Premium: 543.54
#
# --- INITIAL ENTRY #1 at 09:26:59 ---
# CE Entry (SELL): 146.75
# PE Entry (SELL): 204.8
# Gross Premium Received: 351.55
# Stop Loss Premium Level: 386.70500000000004 (Risk: 10.0%)
# Take Profit Premium Level: 281.23999999999995 (Reward: 2x risk)
# Position closed at market close - PnL: -4706.250000000005
#
# === Backtesting for 2021-04-29 ===
#
# Best Entry Found at: 09:20:59
# ATM Strike: 15000.0
# CE Ticker: NIFTY06MAY2115000CE.NFO, Premium: 300.15
# PE Ticker: NIFTY06MAY2115000PE.NFO, Premium: 318.43333333333334
# Total Premium: 618.5833333333333
#
# --- INITIAL ENTRY #1 at 09:20:59 ---
# CE Entry (SELL): 191.95
# PE Entry (SELL): 156.6
# Gross Premium Received: 348.54999999999995
# Stop Loss Premium Level: 383.405 (Risk: 10.0%)
# Take Profit Premium Level: 278.8399999999999 (Reward: 2x risk)
# SL hit at 10:40:59 - PnL: -13743.750000000013
#
# Best Entry Found at: 10:40:59
# ATM Strike: 14900.0
# CE Ticker: NIFTY06MAY2114900CE.NFO, Premium: 208.6
# PE Ticker: NIFTY06MAY2114900PE.NFO, Premium: 216.2375
# Total Premium: 424.8375
#
# --- REENTRY ENTRY #2 at 10:40:59 ---
# CE Entry (SELL): 173.75
# PE Entry (SELL): 203.25
# Gross Premium Received: 377.0
# Stop Loss Premium Level: 414.70000000000005 (Risk: 10.0%)
# Take Profit Premium Level: 301.5999999999999 (Reward: 2x risk)
# Position closed at market close - PnL: 5250.0
#
# === Backtesting for 2021-04-30 ===
#
# Best Entry Found at: 09:33:59
# ATM Strike: 15000.0
# CE Ticker: NIFTY06MAY2115000CE.NFO, Premium: 385.79
# PE Ticker: NIFTY06MAY2115000PE.NFO, Premium: 398.925
# Total Premium: 784.715
#
# --- INITIAL ENTRY #1 at 09:33:59 ---
# CE Entry (SELL): 93.7
# PE Entry (SELL): 275.0
# Gross Premium Received: 368.7
# Stop Loss Premium Level: 405.57 (Risk: 10.0%)
# Take Profit Premium Level: 294.96 (Reward: 2x risk)
# SL hit at 14:04:59 - PnL: -15449.999999999996
#
# Best Entry Found at: 14:04:59
# ATM Strike: 14700.0
# CE Ticker: NIFTY06MAY2114700CE.NFO, Premium: 325.1875
# PE Ticker: NIFTY06MAY2114700PE.NFO, Premium: 296.35
# Total Premium: 621.5375
#
# --- REENTRY ENTRY #2 at 14:04:59 ---
# CE Entry (SELL): 164.5
# PE Entry (SELL): 170.55
# Gross Premium Received: 335.05
# Stop Loss Premium Level: 368.55500000000006 (Risk: 10.0%)
# Take Profit Premium Level: 268.0399999999999 (Reward: 2x risk)
# Position closed at market close - PnL: -2925.000000000004
#
# ==== Performance Summary ====
# Total Days     : 19
# Total Trades   : 25
# Avg Trades/Day : 1.32
# Avg Entries/Day: 1.32
# Win Rate (Days): 57.89%
# Win Rate (Trades): 56.00%
# Total Return   : ₹45318.75 (4.53%)
# Max Drawdown   : ₹31575.00 (2.93%)
# CAGR           : 74.69%
# Sharpe Ratio   : 3.75
#
# ==== Entry Statistics ====
# 1 Entry(ies): 15 days (78.95% of days)
# 2 Entry(ies): 2 days (10.53% of days)
# 3 Entry(ies): 2 days (10.53% of days)
#
# ==== Exit Statistics ====
# Stop Loss Hits : 6 (24.00% of trades)
# Take Profit Hits: 5 (20.00% of trades)
# Market Close   : 14 (56.00% of trades)
#
# ==== Daily Capital & PnL ====
#       Date  Trades  Daily PnL      Capital
# 2021-04-01       3 -12,356.25   987,643.75
# 2021-04-05       3 -21,356.25   966,287.50
# 2021-04-06       1 +17,287.50   983,575.00
# 2021-04-07       1 +15,000.00   998,575.00
# 2021-04-08       1  +7,500.00 1,006,075.00
# 2021-04-09       1 +16,612.50 1,022,687.50
# 2021-04-12       1  -9,525.00 1,013,162.50
# 2021-04-13       1 +18,018.75 1,031,181.25
# 2021-04-15       1  +6,206.25 1,037,387.50
# 2021-04-16       1 +10,162.50 1,047,550.00
# 2021-04-19       1 +25,518.75 1,073,068.75
# 2021-04-20       1  -5,643.75 1,067,425.00
# 2021-04-22       1 -13,068.75 1,054,356.25
# 2021-04-23       1  +7,912.50 1,062,268.75
# 2021-04-26       1 +11,418.75 1,073,687.50
# 2021-04-27       1  +3,206.25 1,076,893.75
# 2021-04-28       1  -4,706.25 1,072,187.50
# 2021-04-29       2  -8,493.75 1,063,693.75
# 2021-04-30       2 -18,375.00 1,045,318.75
#
# Trade results exported to ShortStraddle_Trades_2021-04-01_to_2021-04-30.csv
# Daily results exported to ShortStraddle_Daily_2021-04-01_to_2021-04-30.csv
#
# Backtest completed successfully!
